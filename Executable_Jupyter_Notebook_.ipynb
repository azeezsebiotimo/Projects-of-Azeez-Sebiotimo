# %% [markdown]
# <a href="https://colab.research.google.com/github/azeezsebiotimo/Projects-of-Azeez-Sebiotimo/blob/main/Executable_Jupyter_Notebook_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GWP3 ASSIGNMENT JUPYTER NOTEBOOK REPORT BY GROUP 2817 FOR  MScFE600 (FINANCIAL DATA) COURSE

# %% [markdown]
# ## INTRODUCTION
#
# This is a report on the GWP 3 Assignment of the MScFE 600 Financial Data course given to our group with group number 2817 consisting of three active group members to explain concepts of a selected theme from a set of five themes and use Python code for implementation. First, the group will select a theme as Step 1 task. Then create a Jupyter notebook with 3 macro sections as Step 2 Task. For Step 3 task, we will explain the concepts of the selected theme which will include definitions, equations, formulas, and diagrams with no coding in this section. We will furthermore illustrate the concepts using real-world data as Step4 task. For Step 5 task, we will provide a graphical representation of the concepts and then, summarize the concepts using real-world applications by referencing sources such as a journal article or reputable news source as the final and Step 6 task.

# %% [markdown]
# ## STEP 1 TASK (SELECTION OF THE GROUP’S THEME)
#
# As a group, we are selecting the second theme on the list, which is **“Statistical Related Risk: Volatility & Statistical Related Risk: Correlation”** and the concepts of this theme will be explained and illustrated in this report as required.

# %% [markdown]
# ## STEP 2 TASK (CREATION OF A JUPYTER NOTEBOOK WITH 3 MACRO SECTIONS)
#
# As a group, we created this Jupyter notebook with 3 macro sections and this can be found in .ipynb file named “Executable Jupyter Notebook” in the zipped folder attached with this report  and the PDF document named “ Output of the Executable Jupyter Notebook” which contains the  output from the Jupyter notebook after running the code.

# %% [markdown]
# ## STEP 2 TASK (CREATION OF A JUPYTER NOTEBOOK WITH 3 MACRO SECTIONS)
#
# As a group, we created this Jupyter notebook with 3 macro sections and this can be found in .ipynb file named “Executable Jupyter Notebook” in the zipped folder attached with this report  and the PDF document named “ Output of the Executable Jupyter Notebook” which contains the  output from the Jupyter notebook after running the code.

# %% [markdown]
# ## STEP 3 TASK (EXPLANATION OF THE CONCEPTS OF THE SELECTED THEME)
#
# Below are the terms or keywords related to the **“Statistical Related Risk”** which is our theme of focus in this assignment explained in detail:
#
#
# - Return
# - Average Return
# - Present Value and Future Value
# - Variance
# - Volatility (Standard Deviation)
# - Sharpe Ratio
# - Covariance
# - Correlation
# - Skewness
# - Kurtosis

# %% [markdown]
# ### (A)RETURN
# The term **"return"** of an investment refers to the profit or loss made on an investment relative to the amount of money invested. It is usually expressed as a percentage of the initial investment. It is a number that represents a percent of the total amount invested (or lent) [2].
#
# The concept of return is related to statistical risk in that the potential returns of an investment are often used to determine the level of risk associated with that investment. The higher the potential return, the higher the level of risk that an investor may be exposed to such as the cryptocurrency.
#
# Statistical risk is the likelihood that an investment will generate returns that are different from what was expected. When assessing an investment's risk, it is important to consider both the potential return and the statistical risk associated with that return.
#
# Return is a scale-free summary of an investment opportunity and returns have statistical properties that are easier to work with [1].  There are two formulas for calculating return on an investment: simple returns formula and log returns formula. Using the following variables, we can define the different types of return:  𝑝1 =   final value, 𝑝0=   = initial value.
#
# **Simple Returns Formula**
#
# **Simple Return = $\frac{𝑝1 - 𝑝0}{𝑝0}$**
#
#
#
# For example, if we were calculating yearly returns and on day 1, the portfolio was worth $100 and at the end of the year it was worth $125, the simple return would be:
#
# (125-100)/100 = 0.25 = 25% (Gain)
#
# **Log Returns Formula**
#
# **Log Return = In (𝑝1/ 𝑝0)**
#
# For example, if a portfolio was worth $150 at the start of the year and $190 by the end of the year, the log return would be:
#
# ln (190/150) = 0.236 = 23.6% (Gain)
#
# **Portfolio Return**
# When we have more than one investment or security or asset in a Portfolio, we can Portfolio Return using the formula below:
#
# Portfolio Return = (Weight1 * Return1) +( Weight2 * Return2)
#
# Weight1   = Weight of Investment 1
# Weight2   = Weight of Investment 2
# Return1    = Return of Investment 1
# Return2    = Return of Investment 2
#
# Suppose the expected return of Stock A is 5% and the expected return of Stock B is 11%. If the portfolio is 60% A and 40% B, then the expected portfolio return is:
#
# Return = WeightA * ReturnA + WeightB * ReturnB
#
# =0.60 * 5% + 0.40 * 11% = 7.4%
#
#
# ### (B)  AVERAGE RETURN
#
# The **average return** of an investment is the average profit or loss earned on an investment over a certain period, expressed as a percentage. It is a measure of how much, on average, an investment has gained or lost over a given period.  Considering an income Stock, average return is obtained by taking average of all the daily returns and divide by the number of daily returns [3] or if an investor buys a stock and holds it for five years, the average return over those five years would be the total return divided by the number of years.
#
# Here is an example of how to calculate the average return of an investment in dollars:
#
# Let's say you invested 10,000 in a mutual fund at the beginning of the year. By the end of the year, the value of the fund had increased to 11,000 and you received 500 in dividends during the year. Therefore, your total return for the year was $1,500 ($11,000 + $500 - $10,000).
#
# To calculate the average return for the year, you need to divide the total return by the initial investment and multiply by 100.
#
# In this example:
#
# - Total Return: $1,500
# - Initial Investment: 10,000
# - Average Return: (1,500 / 10,000) x 100 = 0.15 = 15%
#
# So, the average return of your investment in the mutual fund for the year is 15%.
#
# ### (C) PRESENT VALUE AND FUTURE VALUE
#
# The terms **"present value"** and "future value" are used in finance and investing to describe the worth of an investment at different points in time. The concept of return is related to these terms in that the return on an investment is a measure of how much the investment has grown or shrunk in value over time.
#
# Present value refers to the current worth of an investment or future cash flow, based on a discount rate or interest rate. It is the amount of money that would need to be invested now to achieve a certain amount of money in the future, considering the time value of money.
#
# Future value, on the other hand, refers to the value an investment or cash flow will have at a future point in time, based on a certain interest rate or rate of return.
#
# The concept of statistical risk is also related to present value and future value, as the potential return on an investment is often used to determine the level of risk associated with that investment. The higher the potential return, the higher the level of risk that an investor may be exposed to.
#
# Below is an example of how to calculate present value and future value:
#
# Let's say you are considering an investment that will pay you $1,000 in five years. The interest rate is 5%. What is the present value of this investment?
#
# To calculate the present value, you can use the formula:
#
# Present Value = Future Value / (1 + Interest Rate) ^ Number of Years
#
# In this example:
#
#  - Future Value: 1,000 USD
#  - Interest Rate: 5%
#  - Number of Years: 5
#  - Present Value = $1,000 / (1 + 0.05) ^ 5
#  - Present Value = 783.53 USD
#
# **So, the present value of the investment is $783.53.**
#
# To calculate the future value of the investment, you can use the formula:
#
# Future Value = Present Value x (1 + Interest Rate) ^ Number of Years
#
# In this example:
#
# - Present Value: $783.53
# - Interest Rate: 5%
# - Number of Years: 5
# - Future Value = 783.53 x (1 + 0.05) ^ 5
# - Future Value = 1,027.36
#
# **So, the future value of the investment is $1,027.36.**
#
# To calculate the return on this investment, you can use the formula:
#
# Return = (Future Value - Present Value) / Present Value x 100
#
# In this example:
#
#
# Future Value: $1,027.36
#
# Present Value: 783.53 USD
#
# Return = ($1,027.36 - $783.53) / $783.53 x 100
#
# Return = 31.12%
#
# **So, the return on the investment is 31.12%.**
#
# ### (D) VARIANCE
# **Variance** is a statistical measure that quantifies the degree of dispersion or spread of an investment's return from its average return. It is calculated by taking the average of the squared differences between each return and the average return. Variance is a key measure of risk and is often used to estimate the level of statistical risk associated with an investment.
#
# The concept of variance is related to statistical risk in that it is used to quantify the degree of uncertainty associated with an investment's return. The higher the variance of an investment, the greater the statistical risk that the return on that investment will be significantly different from its expected or average return.
#
# For example, let's say you have two stocks, Stock A and Stock B. Stock A has an average annual return of 10% with a variance of 0.04, while Stock B has an average annual return of 10% with a variance of 0.16. This means that the returns of Stock B are more dispersed or spread out than the returns of Stock A, indicating that Stock B has a higher degree of risk associated with its returns.
#
# To calculate the variance of an investment, you can use the following formula:
#
# **Variance = Σ(xi - x)² / n**
#
# Where:
#
# Σ: The sum of the values
# xi: The value of each observation
# x: The average value
# n: The number of observations
# Here is an example of how to calculate the variance of an investment:
#
# Let's say you have the following returns for a stock over the past five years:
#
# Year 1: 5%
#
# Year 2: 10%
#
# Year 3: -3%
#
# Year 4: 8%
#
# Year 5: -2%
#
# To calculate the variance of these returns, you first need to calculate the average return:
#
# Average Return = (5% + 10% - 3% + 8% - 2%) / 5
# Average Return = 3.6%
#
# Next, you need to calculate the squared differences between each return and the average return:
#
# Year 1: (5% - 3.6%)² = 1.44%
#
# Year 2: (10% - 3.6%)² = 38.44%
#
# Year 3: (-3% - 3.6%)² = 44.36%
#
# Year 4: (8% - 3.6%)² = 19.36%
#
# Year 5: (-2% - 3.6%)² = 23.04%
#
# Then, you can calculate the variance by taking the average of these squared differences:
#
# Variance = (1.44% + 38.44% + 44.36% + 19.36% + 23.04%) / 5
# Variance = 25.12%
#
# **So, the variance of the stock over the past five years is 25.12%.**
#
#
# ### (E) VOLATILITY (STANDARD DEVIATION)
#
# **Volatility, also known as standard deviation**, is a statistical measure that indicates the degree of variation of an investment's return from its average return. In other words, volatility measures the degree of risk associated with an investment.
#
# The concept of volatility is related to statistical risk in that it is used to quantify the degree of uncertainty associated with an investment's return. The higher the volatility of an investment, the greater the statistical risk that the return on that investment will be significantly different from its expected or average return.
#
# For example, let's say you are comparing two stocks, Stock A and Stock B. Stock A has an average annual return of 10% with a standard deviation of 5%, while Stock B has an average annual return of 10% with a standard deviation of 15%. This means that the returns of Stock B are more volatile than the returns of Stock A, indicating that Stock B has a higher degree of risk associated with its returns.
#
# To calculate the volatility (standard deviation) of an investment, you can use the following formula:
#
#
# **Standard Deviation = √((Σ(xi - x)²) / n)**
#
#
# Where:
#
# Σ: The sum of the values
#
# xi: The value of each observation
#
# x: The average value
#
# n: The number of observations
#
# Here is an example of how to calculate the standard deviation of an investment:
#
# Let's say you have the following returns for a stock over the past five years:
#
# Year 1: 5%
#
# Year 2: 10%
#
# Year 3: -3%
#
# Year 4: 8%
#
# Year 5: -2%
#
# To calculate the standard deviation of these returns, you first need to calculate the average return:
#
# Average Return = (5% + 10% - 3% + 8% - 2%) / 5
#
# Average Return = 3.6%
#
# Next, you need to calculate the variance, which is the sum of the squared differences between each return and the average return, divided by the number of observations:
#
# Variance = ((5% - 3.6%)² + (10% - 3.6%)² + (-3% - 3.6%)² + (8% - 3.6%)² + (-2% - 3.6%)²) / 5
#
# Variance = 35.84%
#
# Finally, you can calculate the standard deviation by taking the square root of the variance:
#
# Standard Deviation = √35.84%
#
# Standard Deviation = 5.99%
#
# **So, the standard deviation (volatility) of the stock over the past five years is 5.99%.**
#
# ### (F) SHARPE RATIO
#
# **The Sharpe Ratio** is a measure of the risk-adjusted return of an investment, which considers the level of statistical risk associated with the investment. It was developed by Nobel laureate William F. Sharpe and is widely used by investors to evaluate the performance of their investments.
#
#
# The Sharpe Ratio compares the return of an investment to the level of statistical risk taken to achieve that return. A higher Sharpe Ratio indicates a better risk-adjusted return, while a lower Sharpe Ratio indicates a lower risk-adjusted return.
#
# The concept of Sharpe Ratio is related to statistical risk in that it is used to evaluate the level of risk associated with an investment's return, considering the potential return that could be earned from investing in a risk-free asset.
#
# To calculate the Sharpe Ratio of an investment, you can use the following formula:
#
# **Sharpe Ratio = (Rp - Rf) / σp**
#
# Where:
#
# Rp: The average return of the investment
#
# Rf: The risk-free rate of return
#
# σp: The standard deviation of the investment's return
#
# In many cases with interest rates so low, investors will assume the risk-free rate to be 0, making the ratio:
#
#
# Here is an example of how to calculate the Sharpe Ratio of an investment:
#
# Let's say you invested in a stock that had an average annual return of 15% over the past five years, and the risk-free rate of return was 2%. The standard deviation of the stock's return was 10%.
#
# To calculate the Sharpe Ratio of the stock, you can use the formula:
#
# Sharpe Ratio = (Rp - Rf) / σp
#
# In this example:
#
# Rp: 15%
#
# Rf: 2%
#
# σp: 10%
#
# Sharpe Ratio = (15% - 2%) / 10%
#
# **Sharpe Ratio = 1.3**
#
# **So, the Sharpe Ratio of the stock is 1.3. A Sharpe Ratio of 1.3 indicates that the stock has provided a good risk-adjusted return, as the return is higher than the risk-free rate and the level of statistical risk is not too high.**
#
# ### (G) COVARIANCE
#
# **Covariance** is a statistical measure that indicates the degree to which the returns of two investments are related or move together. It measures the extent to which the returns of one investment vary in relation to the returns of another investment.
#
# The concept of covariance is related to statistical risk in that it is used to quantify the degree of risk associated with investing in multiple assets. When investing in multiple assets, it is important to consider not only the risk associated with each asset individually but also the risk associated with the relationship between the assets. Assets that have a high covariance with each other can amplify the overall risk of a portfolio, while assets with a low covariance can help to reduce the overall risk of a portfolio. Covariance provides us some insight into how two variables move together. A positive covariance between stock returns would indicate that when one stock goes up, so does the other and vice versa. A negative covariance would mean that the two stocks move inversely, i.e., when one goes up, the other goes down.[1]
#
# To calculate the covariance between two investments, you can use the following formula:
#
#
# **Covariance = Σ((xi - x) * (yi - y)) / N**
#
# Where:
#
# Σ: The sum of the values
#
# xi: The value of each observation for the first investment x
#
# yi: The value of each observation for the second investment y
#
# x: The average value for the first investment x
#
# y: The average value for the second investment y
#
# N: The number of observations
#
# Below is an example of how to calculate the covariance between two investments:
#
# Let's say you have the following returns for two stocks, Stock A and Stock B, over the past five years:
#
# Stock A: 5%, 10%, -3%, 8%, -2%
#
# Stock B: 8%, -4%, 6%, 10%, 2%
#
#
# To calculate the covariance between these two stocks, you first need to calculate the average return for each stock:
#
# Average Return for Stock A = (5% + 10% - 3% + 8% - 2%) / 5
#
# Average Return for Stock A = 3.6%
#
# Average Return for Stock B = (8% - 4% + 6% + 10% + 2%) / 5
#
# Average Return for Stock B = 4.4%
#
# Next, you need to calculate the differences between each return and the average return for each stock:
#
# For Stock A:
#
# (5% - 3.6%) = 1.4%
#
# (10% - 3.6%) = 6.4%
#
# (-3% - 3.6%) = -6.6%
#
# (8% - 3.6%) = 4.4%
#
# (-2% - 3.6%) = -5.6%
#
# For Stock B:
#
# (8% - 4.4%) = 3.6%
#
# (-4% - 4.4%) = -8.4%
#
# (6% - 4.4%) = 1.6%
#
# (10% - 4.4%) = 5.6%
#
# (2% - 4.4%) = -2.4%
#
# Then, you can calculate the covariance by taking the sum of the products of the differences for each observation and dividing by the number of observations:
#
# Covariance = ((1.4% * 3.6%) + (6.4% * 3.6%) + (-6.6% * 3.6%) + (4.4% * 3.6%) + (-5.6% * 3.6%)) / 5
#
# Covariance = 0.19%
#
# **So, the covariance between Stock A and Stock B is 0.19%.**
#
# ### (H) CORRELATION
#
# **Correlation** is a statistical measure that indicates the degree to which the returns of two investments are related or move together, but it also considers the scale of the returns of each investment. It measures the strength and direction of the linear relationship between the returns of two investments.
#
# The concept of correlation is related to statistical risk in that it is used to quantify the degree of risk associated with investing in multiple assets. A high correlation between two assets indicates that they move together and have a similar level of risk, while a low correlation indicates that they move independently of each other and have a different level of risk. A benefit of correlation over covariance is that correlation is capped from –1 to 1 while covariance can be from –inf to inf. This makes covariance a harder statistic to understand intuitively. Correlation is also proportional, which will be shown in the video below.[1]
#
# To calculate the correlation between two investments, you can use the following formula:
#
# **Correlation = Covariance / (σx * σy)**
#
# Where:
#
# Covariance: The covariance between the two investments
#
# σx: The standard deviation of the returns of the first investment x
#
# σy: The standard deviation of the returns of the second investment x
#
# Below is an example of how to calculate the correlation between two investments:
#
# Let's say you have the following returns for two stocks, Stock A and Stock B, over the past five years:
#
# Stock A: 5%, 10%, -3%, 8%, -2%
#
# Stock B: 8%, -4%, 6%, 10%, 2%
#
# To calculate the correlation between these two stocks, you first need to calculate the covariance between them, which we calculated to be 0.19% in the previous example.
#
# Next, you need to calculate the standard deviation of the returns for each stock:
#
# Standard Deviation for Stock A = 5.99%
#
# Standard Deviation for Stock B = 5.53%
#
# Then, you can calculate the correlation by dividing the covariance by the product of the standard deviations:
#
# Correlation = 0.19% / (5.99% * 5.53%)
#
# **Correlation = 0.59**
#
# **So, the correlation between Stock A and Stock B is 0.59. A correlation of 0.59 indicates a moderate positive relationship between the two stocks, meaning that they tend to move together to some extent. However, the correlation is not strong enough to suggest that they are highly correlated and move in lockstep with each other.**
#
#
# ### (I) SKEWNESS
#
# **Skewness** is a statistical measure that indicates the degree of asymmetry in the distribution of the returns of an investment. It measures whether the distribution of returns is symmetric (i.e., bell-shaped) or skewed (i.e., one-tailed), and the direction of the skewness.
#
# The concept of skewness is related to statistical risk in that it is used to quantify the degree of risk associated with an investment's return distribution. A skewed return distribution can indicate a higher level of risk, as it suggests that there is a greater likelihood of extreme returns (either positive or negative) than a symmetric distribution.
#
# To calculate the skewness of an investment's return distribution, you can use the following formula:
#
# **Skewness = (Σ(xi - x)³ / n) / σ³**
#
# Where:
#
# Σ: The sum of the values
#
# xi: The value of each observation
#
# x: The average value
#
# n: The number of observations
#
# σ: The standard deviation
#
# Below is an example of how to calculate the skewness of an investment's return distribution:
#
# Let's say you have the following returns for a stock over the past five years:
#
# Year 1: 5%
#
# Year 2: 10%
#
# Year 3: -3%
#
# Year 4: 8%
#
# Year 5: -2%
#
# To calculate the skewness of these returns, you first need to calculate the average return and the standard deviation:
#
# Average Return = (5% + 10% - 3% + 8% - 2%) / 5
#
# Average Return = 3.6%
#
# Standard Deviation = 5.99%
#
#
#
# Next, you need to calculate the third moment of the distribution, which is the sum of the cubed differences between each return and the average return, divided by the number of observations:
#
# Third Moment = ((5% - 3.6%)³ + (10% - 3.6%)³ + (-3% - 3.6%)³ + (8% - 3.6%)³ + (-2% - 3.6%)³) / 5
#
# Third Moment = -4.90%
#
# Finally, you can calculate the skewness by dividing the third moment by the cube of the standard deviation:
#
# Skewness = -4.90% / (5.99%)³
#
# **Skewness = -1.07**
#
# **So, the skewness of the return distribution for the stock is -1.07, which indicates a negative skewness, suggesting that the distribution is skewed to the left, with a higher probability of negative returns.**
#
# ### (J) KURTOSIS
#
# **Kurtosis** is a statistical measure that indicates the degree of peakedness or flatness of the distribution of returns of an investment, compared to a normal distribution. It measures the extent to which the tails of the distribution are fatter or thinner than a normal distribution.
#
# The concept of kurtosis is related to statistical risk in that it is used to quantify the degree of risk associated with an investment's return distribution. A distribution with high kurtosis indicates a higher likelihood of extreme returns, either positive or negative, compared to a normal distribution. This means that the investment has a higher level of risk associated with its returns.
#
# To calculate the kurtosis of an investment's return distribution, you can use the following formula:
#
# **Kurtosis = (Σ(xi - x)⁴ / n) / σ⁴**
#
# Where:
#
# Σ: The sum of the values
#
# xi: The value of each observation
#
# x: The average value
#
# n: The number of observations
# σ: The standard deviation
#
# Below is an example of how to calculate the kurtosis of an investment's return distribution:
#
#
#
#
# Let's say you have the following returns for a stock over the past five years:
#
# Year 1: 5%
# Year 2: 10%
# Year 3: -3%
# Year 4: 8%
# Year 5: -2%
#
# To calculate the kurtosis of these returns, you first need to calculate the average return and the standard deviation:
#
# Average Return = (5% + 10% - 3% + 8% - 2%) / 5
#
# Average Return = 3.6%
#
# Standard Deviation = 5.99%
#
# Next, you need to calculate the fourth moment of the distribution, which is the sum of the fourth powers of the differences between each return and the average return, divided by the number of observations:
#
# Fourth Moment = ((5% - 3.6%) ⁴ + (10% - 3.6%)⁴ + (-3% - 3.6%)⁴ + (8% - 3.6%)⁴ + (-2% - 3.6%)⁴) / 5
#
# Fourth Moment = 176.25%
#
# Finally, you can calculate the kurtosis by dividing the fourth moment by the fourth power of the standard deviation, and then subtracting 3 (the kurtosis of a normal distribution):
#
# Kurtosis = (176.25% / (5.99%) ⁴) - 3
#
# **Kurtosis = 1.43**
#
# **So, the kurtosis of the return distribution for the stock is 1.43, which indicates a leptokurtic distribution, meaning that it is more peaked and has fatter tails than a normal distribution. This suggests that the investment has a higher level of risk associated with its returns, as there is a higher likelihood of extreme returns.**

# %% [markdown]
# ## STEP 4 TASK (ILLUSTRATION OF THE CONCEPTS USING REAL-WORLD DATA)
#
# For the section of the task, we are importing real data from Yahoo Finance for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock for the last two years (28-April-2021 to 29-April-2023) which will be used for illustration of the concepts and terms related to our theme **“Statistical Related Risk”** explained in Step 3 task.
#
# ### (A) RETURN
#
# The Python code below calculates the daily returns for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. The code in Jupyter Notebook first imports the yfinance library and sets the start and end dates (28-April-2021 to 29-April-2023) for the data. It then uses the yf.download() function to get the iShares 20+ Year Treasury Bond ETF (TLT)  and Microsoft Corporation (MSFT) Income Stock data from Yahoo Finance. It calculates daily returns using the formula: daily return=(Close-Open)/Open and creates tables with the columns "Date", "Open Price", "Close Price", and "Daily Returns" for each of the securities using the pd.DataFrame() function. Finally, it prints the table  shown below.

# %%
# To Calculate Return for an ETF and a Stock Using Real Data
import yfinance as yf
import pandas as pd

# set the start and end dates
start_date = '2021-04-28'
end_date = '2023-04-29'

# download the data for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock
tlt = yf.download('TLT', start=start_date, end=end_date)
msft = yf.download('MSFT', start=start_date, end=end_date)

# calculate daily returns for iShares 20+ Year Treasury Bond ETF (TLT)
tlt['Daily Returns'] = (tlt['Close'] - tlt['Open']) / tlt['Open']

# create table for iShares 20+ Year Treasury Bond ETF (TLT) with columns "Date", "Open Price", "Close Price", and "Daily Returns"
tlt_table = pd.concat([tlt['Open'], tlt['Close'], tlt['Daily Returns']], axis=1)
tlt_table.columns = ["Open Price", "Close Price", "Daily Returns"]
tlt_table.index.name = "Date"

# calculate daily returns for Microsoft Corporation (MSFT) Income Stock
msft['Daily Returns'] = (msft['Close'] - msft['Open']) / msft['Open']

# create table for Microsoft Corporation (MSFT) Income Stock with columns "Date", "Open Price", "Close Price", and "Daily Returns"
msft_table = pd.concat([msft['Open'], msft['Close'], msft['Daily Returns']], axis=1)
msft_table.columns = ["Open Price", "Close Price", "Daily Returns"]
msft_table.index.name = "Date"

# display the tables
print("iShares 20+ Year Treasury Bond ETF (TLT) Data:\n")
display(tlt_table)
print("\nMicrosoft Corporation (MSFT) Income Stock Data:\n")
display(msft_table)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# iShares 20+ Year Treasury Bond ETF (TLT) Data:
#             Open Price  Close Price  Daily Returns
# Date
# 2021-04-28  138.649994   138.729996       0.000577
# 2021-04-29  137.449997   138.320007       0.006330
# 2021-04-30  138.509995   138.639999       0.000939
# 2021-05-03  138.699997   138.520004      -0.001298
# 2021-05-04  139.490005   139.460007      -0.000215
# ...                ...          ...            ...
# 2023-04-24  104.959999   105.410004       0.004287
# 2023-04-25  106.330002   106.959999       0.005925
# 2023-04-26  106.790001   105.820000      -0.009083
# 2023-04-27  105.199997   104.769997      -0.004087
# 2023-04-28  106.209999   106.459999       0.002354
#
# [505 rows x 3 columns]
# Microsoft Corporation (MSFT) Income Stock Data:
#             Open Price  Close Price  Daily Returns
# Date
# ...

# %% [markdown]
# **These results in Python exactly matched the results of daily returns of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock done in sheet “Statistics” of the Dataset Excel Spreadsheet named “Datasets Used in Step 4 Task” in the zipped folder attached to this report for reference.**

# %% [markdown]
# ### (B) AVERAGE RETURN
# The code below calculates the average returns for the two investments, iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock). The yf.download() function is used to get the , iShares 20+ Year Treasury Bond ETF (TLT)and Microsoft Corporation (MSFT) Income Stock data from Yahoo Finance, and it calculates the  daily returns. The mean () function is then used to calculate the average return for each security.
#
# Finally, a table is created using the pd.DataFrame() function, with the average returns for TLT and MSFT displayed in columns and the row labeled "Average Return". The resulting table and codes are shown  below:

# %%
# To Calculate Average Returns  of an ETF and an Income Stock Using Real-Data
import yfinance as yf
import pandas as pd

# Download data for TLT and MSFT from Yahoo Finance
tickers = ["TLT", "MSFT"]
data = yf.download(tickers, start="2021-04-28", end="2023-04-29")

# Calculate daily returns
daily_returns = (data["Close"] - data["Open"]) / data["Open"]

# Create a table with columns "iShares 20+ Year Treasury Bond ETF (TLT)" and "Microsoft Corporation (MSFT) Income Stock"
# and row "Average Return"
average_returns = pd.DataFrame({
    "iShares 20+ Year Treasury Bond ETF (TLT)": daily_returns["TLT"].mean(),
    "Microsoft Corporation (MSFT) Income Stock": daily_returns["MSFT"].mean()
}, index=["Average Return"])

# Display the table
display(average_returns)
# Out:
# [*********************100%***********************]  2 of 2 completed
#                 iShares 20+ Year Treasury Bond ETF (TLT)  \
# Average Return                                  0.000107
#
#                 Microsoft Corporation (MSFT) Income Stock
# Average Return                                   0.000439

# %% [markdown]
# **From the output of code above, the average return of iShares 20+ Year Treasury Bond ETF (TLT) is 0.000107 and the average return of Microsoft Corporation (MSFT) Income Stock is 0.000439. These results in Python exactly matched the results from calculation done in sheet “Statistics” of the Dataset Excel Spreadsheet named “Datasets Used in Step 4 Task” in the zipped folder attached to this report for reference.**

# %% [markdown]
# ### (C) PRESENT VALUE AND FUTURE VALUE
# The python code below shows how to calculate present value and future value of investments, iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock assuming an initial investment of $1,000. In this code, the yf.download() function is used to get the iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock data from Yahoo Finance, and it  calculates the  daily returns.
#
# Note that this assumes that the initial investment is made on the first day of the data range (28-April-2021), and the ending value and total return are calculated based on the last day of the data range (29-April-2023).
#
# The results are then printed for each security, including the initial investment, ending value, and total return as shown below.

# %%
# To show how to calculate Present Value and Future Value of an ETF and an Income Stock  Real-Data
import yfinance as yf

# Import data for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock
tlt_data = yf.download("TLT", start="2021-04-28", end="2023-04-29")
msft_data = yf.download("MSFT", start="2021-04-28", end="2023-04-29")

# Calculate daily returns for both stocks
tlt_data["Daily Return"] = (tlt_data["Close"] - tlt_data["Open"]) / tlt_data["Open"]
msft_data["Daily Return"] = (msft_data["Close"] - msft_data["Open"]) / msft_data["Open"]

# Calculate average daily return for both stocks
tlt_avg_return = tlt_data["Daily Return"].mean()
msft_avg_return = msft_data["Daily Return"].mean()

# Set initial investment
initial_investment = 1000

# Calculate present value and future value for Microsoft Corporation (MSFT) Income Stock
msft_pv = initial_investment
msft_fv = msft_pv * (1 + msft_avg_return) ** len(msft_data)
msft_return = (msft_fv - msft_pv) / msft_pv

# Calculate present value and future value for iShares 20+ Year Treasury Bond ETF (TLT)
tlt_pv = initial_investment
tlt_fv = tlt_pv * (1 + tlt_avg_return) ** len(tlt_data)
tlt_return = (tlt_fv - tlt_pv) / tlt_pv

# Print investment results
print("\nMicrosoft Corporation (MSFT) Income Stock Investment Results:")
print("Initial Investment(Present Value): $", msft_pv)
print("Ending Value(Future Value): $", round(msft_fv, 2))
print("Total Return: ", round(msft_return * 100, 2), "%")

print("\niShares 20+ Year Treasury Bond ETF (TLT) Investment Results:")
print("Initial Investment(Present Value): $", tlt_pv)
print("Ending Value (Future Value): $", round(tlt_fv, 2))
print("Total Return: ", round(tlt_return * 100, 2), "%")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# Microsoft Corporation (MSFT) Income Stock Investment Results:
# Initial Investment(Present Value): $ 1000
# Ending Value(Future Value): $ 1248.17
# Total Return:  24.82 %
#
# iShares 20+ Year Treasury Bond ETF (TLT) Investment Results:
# Initial Investment(Present Value): $ 1000
# Ending Value (Future Value): $ 1055.27
# Total Return:  5.53 %

# %% [markdown]
# ### (D) VARIANCE
# The python code below calculates the variance of the returns of the iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. In this code, the yf.download() function is used to get the iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock data from Yahoo Finance, and it calculates daily returns.
#
# The var() function is used to calculate the variance of the daily returns for each security.
#
# Finally, a table is created using the pd.DataFrame() function, with the variance of the daily returns displayed for each security in a single row. The code and resulting table can be seen below :

# %%
# To Calculate Variance of the returns of an ETF and an Income Stock  Real-Data
import yfinance as yf
import pandas as pd

# Download data for TLT and MSFT
tlt = yf.download("TLT", start="2021-04-28", end="2023-04-29")
msft = yf.download("MSFT", start="2021-04-28", end="2023-04-29")

# Calculate daily returns
tlt['Daily Return'] = (tlt['Close'] - tlt['Open']) / tlt['Open']
msft['Daily Return'] = (msft['Close'] - msft['Open']) / msft['Open']

# Calculate variance of daily returns
tlt_variance = tlt['Daily Return'].var()
msft_variance = msft['Daily Return'].var()

# Create table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [tlt_variance], 'Microsoft Corporation (MSFT) Income Stock': [msft_variance]}
table = pd.DataFrame(data, index=['Variance'])

# Display table
display(table)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#           iShares 20+ Year Treasury Bond ETF (TLT)  \
# Variance                                  0.000062
#
#           Microsoft Corporation (MSFT) Income Stock
# Variance                                   0.000239

# %% [markdown]
# **From the output of code above, the variance of returns of iShares 20+ Year Treasury Bond ETF (TLT) is 0.000062 and the variance of returns of Microsoft Corporation (MSFT) Income Stock is 0.000239. These results in Python exactly matched the results from calculation done in sheet “Statistics” of the Dataset Excel Spreadsheet named “Datasets Used in Step 4 Task” in the zipped folder attached to this report for reference.**

# %% [markdown]
# ### (E) VOLATILITY (STANDARD DEVIATION)
# The python code below calculates the standard deviation (volatility)  of the returns of the iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. The Python code first imports real data or prices for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock from yfinance, then calculates daily returns, and calculates the standard deviation of the daily returns, then  output a table with two rows and one column labeled "Standard Deviation (Volatility)" and the corresponding values for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock  as shown below.

# %%
# To Calculate Standard Deviation (Volatility) of the returns of an ETF and an Income Stock  Real-Data
import yfinance as yf
import pandas as pd

# Import data
tlt = yf.download('TLT', start='2021-04-28', end='2023-04-29')
msft = yf.download('MSFT', start='2021-04-28', end='2023-04-29')

# Calculate daily returns
tlt['Daily Return'] = (tlt['Close'] - tlt['Open']) / tlt['Open']
msft['Daily Return'] = (msft['Close'] - msft['Open']) / msft['Open']

# Calculate standard deviation of daily returns
tlt_volatility = tlt['Daily Return'].std()
msft_volatility = msft['Daily Return'].std()

# Create table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [tlt_volatility], 'Microsoft Corporation (MSFT) Income Stock': [msft_volatility]}
table = pd.DataFrame(data, index=['Standard Deviation (Volatility)'])

# Display table
display(table)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                                  iShares 20+ Year Treasury Bond ETF (TLT)  \
# Standard Deviation (Volatility)                                  0.007891
#
#                                  Microsoft Corporation (MSFT) Income Stock
# Standard Deviation (Volatility)                                   0.015461

# %% [markdown]
# **From the output of code above, the Standard Deviation (Volatility) of returns of iShares 20+ Year Treasury Bond ETF (TLT) is 0.007891 and the Standard Deviation (Volatility)   of returns of Microsoft Corporation (MSFT) Income Stock is 0.015461.**
#
# **These results in Python exactly matched the results from calculation done in sheet “Statistics” of the Dataset Excel Spreadsheet named “Datasets Used in Step 4 Task” in the zipped folder attached to this report for reference.**

# %% [markdown]
# ### (F) SHARPE RATIO
# The python code below calculates the Sharpe Ratio of the returns of the iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. The code first downloads the stock data for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) from Yahoo Finance, then calculates the daily returns for each stock using the formula provided. It then calculates the average daily return and standard deviation of the daily returns for each stock. The Sharpe Ratio is then calculated for each stock using the average daily return, standard deviation, and a risk-free rate of 0%. Finally, a table is created and displayed showing the Sharpe Ratio for each stock shown  below.

# %%
# To Calculate Sharp Ratio of an ETF and an Income Stock  Real-Data
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Download TLT and MSFT data from Yahoo Finance
tlt = yf.download('TLT', start='2021-04-28', end='2023-04-29')
msft = yf.download('MSFT', start='2021-04-28', end='2023-04-29')

# Calculate daily returns for TLT and MSFT
tlt['daily_return'] = (tlt['Close'] - tlt['Open']) / tlt['Open']
msft['daily_return'] = (msft['Close'] - msft['Open']) / msft['Open']

# Calculate average daily return for TLT and MSFT
tlt_avg_return = np.mean(tlt['daily_return'])
msft_avg_return = np.mean(msft['daily_return'])

# Calculate standard deviation of daily return for TLT and MSFT
tlt_std_dev = np.std(tlt['daily_return'])
msft_std_dev = np.std(msft['daily_return'])

# Calculate Sharpe Ratio for TLT and MSFT with risk-free rate of 0
rf_rate = 0
tlt_sharpe_ratio = (tlt_avg_return - rf_rate) / tlt_std_dev
msft_sharpe_ratio = (msft_avg_return - rf_rate) / msft_std_dev

# Create table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [tlt_sharpe_ratio], 'Microsoft Corporation (MSFT) Income Stock': [msft_sharpe_ratio]}
table = pd.DataFrame(data, index=['Sharpe Ratio'])

# Display table
display(table)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#               iShares 20+ Year Treasury Bond ETF (TLT)  \
# Sharpe Ratio                                  0.013514
#
#               Microsoft Corporation (MSFT) Income Stock
# Sharpe Ratio                                   0.028426

# %% [markdown]
# **From the output of code above, the Sharpe Ratio of iShares 20+ Year Treasury Bond ETF (TLT) is 0.0135 and the Sharpe Ratio of Microsoft Corporation (MSFT) Income Stock is 0.0284. These results in Python exactly matched the results from calculation done in sheet “Statistics” of the Dataset Excel Spreadsheet named “Datasets Used in Step 4 Task” in the zipped folder attached to this report for reference.**

# %% [markdown]
# ### (G) COVARIANCE
# The python code below calculates the covariance between the daily returns of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. This code first imports the data for TLT and MSFT, calculates their daily returns, and then calculates the average daily return for each investment. Finally, it calculates the covariance between the daily returns of TLT and MSFT and displays the result in a table. Note that the covariance is the same for both investments, so both columns in the table have the same value.

# %%
# To Calculate Covariance between an ETF and an Income Stock  Using Real-Data
# Import data
tlt_data = yf.download("TLT", start="2021-04-28", end="2023-04-29")
msft_data = yf.download("MSFT", start="2021-04-28", end="2023-04-29")

# Calculate daily returns
tlt_data["Daily Return"] = (tlt_data["Close"] - tlt_data["Open"]) / tlt_data["Open"]
msft_data["Daily Return"] = (msft_data["Close"] - msft_data["Open"]) / msft_data["Open"]

# Calculate average daily return
tlt_avg_return = tlt_data["Daily Return"].mean()
msft_avg_return = msft_data["Daily Return"].mean()

# Calculate covariance between daily returns
covariance = tlt_data["Daily Return"].cov(msft_data["Daily Return"])

# Create table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [covariance], 'Microsoft Corporation (MSFT) Income Stock': [covariance]}
table = pd.DataFrame(data, index=['Covariance'])

# Display table
display(table)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#             iShares 20+ Year Treasury Bond ETF (TLT)  \
# Covariance                             -4.864068e-07
#
#             Microsoft Corporation (MSFT) Income Stock
# Covariance                              -4.864068e-07

# %% [markdown]
# **From the output of code above, the Covariance between iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock is approximately 0.00000049. These results in Python exactly matched the results from calculation done in sheet “Statistics” of the Dataset Excel Spreadsheet named “Datasets Used in Step 4 Task” in the zipped folder attached to this report for reference**

# %% [markdown]
# ### (H) CORRELATION
# The python code below calculates the correlation between the daily returns of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. The code first imports real data or prices for the last two years from 28-April-2021 to 29-Apr-2023 for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock from yfinance, calculate daily returns, average daily return for each investment, and correlation between the daily returns of TLT and MSFT, and display the results in a table as seen  below.

# %%
# To Calculate Correlation between an ETF and an Income Stock  Using Real-Data
import yfinance as yf
import pandas as pd

# Import data for TLT and MSFT
tlt = yf.Ticker("TLT")
msft = yf.Ticker("MSFT")
tlt_data = tlt.history(start="2021-04-28", end="2023-04-29")
msft_data = msft.history(start="2021-04-28", end="2023-04-29")

# Calculate daily returns
tlt_data["Daily Return"] = (tlt_data["Close"] - tlt_data["Open"]) / tlt_data["Open"]
msft_data["Daily Return"] = (msft_data["Close"] - msft_data["Open"]) / msft_data["Open"]

# Calculate average daily return
tlt_avg_return = tlt_data["Daily Return"].mean()
msft_avg_return = msft_data["Daily Return"].mean()

# Calculate correlation between daily returns
corr = tlt_data["Daily Return"].corr(msft_data["Daily Return"])

# Create table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [corr], 'Microsoft Corporation (MSFT) Income Stock': [corr]}
table = pd.DataFrame(data, index=['Correlation'])

# Display table
display(table)
# Out:
#              iShares 20+ Year Treasury Bond ETF (TLT)  \
# Correlation                                 -0.003987
#
#              Microsoft Corporation (MSFT) Income Stock
# Correlation                                  -0.003987

# %% [markdown]
# **From the output of code above, the Correlation between iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock is approximately -0.003987. These results in Python exactly matched the results from calculation done in sheet “Statistics” of the Dataset Excel Spreadsheet named “Datasets Used in Step 4 Task” in the zipped folder attached to this report for reference.**

# %% [markdown]
# ### (I) SKEWNESS
# The python code below calculates the skewness of the returns of the iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock and displays the results in a table as shown below .

# %%
# To Calculate Skewness of the returns of an ETF and an Income Stock  Real-Data
import yfinance as yf
import pandas as pd
import numpy as np
from scipy.stats import skew

# Import data for TLT and MSFT
tlt = yf.download('TLT', start='2021-04-28', end='2023-04-29')
msft = yf.download('MSFT', start='2021-04-28', end='2023-04-29')

# Calculate daily returns for TLT and MSFT
tlt['Daily Return'] = (tlt['Close'] - tlt['Open']) / tlt['Open']
msft['Daily Return'] = (msft['Close'] - msft['Open']) / msft['Open']

# Calculate average daily return for TLT and MSFT
tlt_avg_return = tlt['Daily Return'].mean()
msft_avg_return = msft['Daily Return'].mean()

# Calculate skewness for TLT and MSFT
tlt_skewness = skew(tlt['Daily Return'].dropna())
msft_skewness = skew(msft['Daily Return'].dropna())

# Create table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [tlt_skewness], 'Microsoft Corporation (MSFT) Income Stock': [msft_skewness]}
table = pd.DataFrame(data, index=['Skewness'])

# Display table
display(table)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#           iShares 20+ Year Treasury Bond ETF (TLT)  \
# Skewness                                  0.095261
#
#           Microsoft Corporation (MSFT) Income Stock
# Skewness                                   0.271172

# %% [markdown]
# **From the output of code above, the Skewness of returns of iShares 20+ Year Treasury Bond ETF (TLT) is approximately 0.0952 and the Skewness of returns of Microsoft Corporation (MSFT) Income Stock is approximately 0.272. These results in Python exactly matched the results from calculation done in sheet “Statistics” of the Dataset Excel Spreadsheet named “Datasets Used in Step 4 Task” in the zipped folder attached to this report for reference.**

# %% [markdown]
# ### (J) KURTOSIS
# The python code below calculates the Kurtosis of the returns of the iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock and displays the results in a table as shown below.

# %%
# To Calculate Kurtosis of Returns of an ETF and an Income Stock  Real-Data
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Download data
tlt = yf.download('TLT', start='2021-04-28', end='2023-04-29')
msft = yf.download('MSFT', start='2021-04-28', end='2023-04-29')

# Calculate daily returns
tlt['Daily Return'] = (tlt['Close'] - tlt['Open']) / tlt['Open']
msft['Daily Return'] = (msft['Close'] - msft['Open']) / msft['Open']

# Calculate kurtosis
tlt_kurtosis = round(tlt['Daily Return'].kurtosis(), 4)
msft_kurtosis = round(msft['Daily Return'].kurtosis(), 4)

# Create table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [tlt_kurtosis], 'Microsoft Corporation (MSFT) Income Stock': [msft_kurtosis]}
table = pd.DataFrame(data, index=['Kurtosis'])

# Display table
display(table)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#           iShares 20+ Year Treasury Bond ETF (TLT)  \
# Kurtosis                                    0.9265
#
#           Microsoft Corporation (MSFT) Income Stock
# Kurtosis                                     2.1312

# %% [markdown]
# **From the output of code above, the Kurtosis of returns of iShares 20+ Year Treasury Bond ETF (TLT) is approximately 0.9265 and the Kurtosis of returns of Microsoft Corporation (MSFT) Income Stock is approximately 2.1312. These results in Python exactly matched the results from calculation done in sheet “Statistics” of the Dataset Excel Spreadsheet named “Datasets Used in Step 4 Task” in the zipped folder attached to this report for reference.**

# %% [markdown]
# ## STEP 5 TASK (GRAPHICAL REPRESENTATION OF THE CONCEPTS OF THE THEME)
#
# This section shows graphical representation of the concepts and terms related to our theme **“Statistical Related Risk”** shown in Step 4 task using python codes on the imported real word data from Yahoo Finance for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock for the last two years (28-April-2021 to 29-April-2023).
#
# ### (A) RETURN
# The code below shows the graph of the trend of the daily returns of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock . The code first imports the yfinance, pandas, and matplotlib.pyplot libraries, sets the start and end dates for the data, and uses the yf.download() function to get the iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock data from Yahoo Finance. It calculates daily returns using the formula: daily return=(Close-Open)/Open and plots a graph of daily returns for each of the securities using the plot() function. The title(), xlabel(), and ylabel() functions are used to add labels to the graph. Finally, the show() function is called to display the graphs as seen below. The frequency of the daily returns for the two investments, iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock.

# %%
# To plot graph of Daily Return Trends for an ETF and an Income Stock Using Real-Data
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# define the ticker symbols
tickers = ["TLT", "MSFT"]

# download the data
data = yf.download(tickers, start="2021-04-28", end="2023-04-29")

# calculate the daily returns
daily_returns = (data["Close"] - data["Open"]) / data["Open"]

# plot the daily returns trend for iShares 20+ Year Treasury Bond ETF (TLT)
plt.figure(figsize=(10, 5))
plt.plot(daily_returns["TLT"])
plt.title("Daily Returns Trend for iShares 20+ Year Treasury Bond ETF (TLT)")
plt.xlabel("Date")
plt.ylabel("Daily Returns")
plt.show()

# plot the daily returns trend for Microsoft Corporation (MSFT) Income Stock
plt.figure(figsize=(10, 5))
plt.plot(daily_returns["MSFT"])
plt.title("Daily Returns Trend for Microsoft Corporation (MSFT) Income Stock")
plt.xlabel("Date")
plt.ylabel("Daily Returns")
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
# To plot graph of Daily Return Trends for an ETF and an Income Stock Using Real-Data
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# define the ticker symbols
tickers = ["TLT", "MSFT"]

# download the data
data = yf.download(tickers, start="2021-04-28", end="2023-04-29")

# calculate the daily returns
daily_returns = (data["Close"] - data["Open"]) / data["Open"]

# plot the daily returns trend for iShares 20+ Year Treasury Bond ETF (TLT)
plt.figure(figsize=(10, 5))
plt.plot(daily_returns["TLT"])
plt.title("Daily Returns Trend for iShares 20+ Year Treasury Bond ETF (TLT)")
plt.xlabel("Date")
plt.ylabel("Daily Returns")
plt.show()

# plot the daily returns trend for Microsoft Corporation (MSFT) Income Stock
plt.figure(figsize=(10, 5))
plt.plot(daily_returns["MSFT"])
plt.title("Daily Returns Trend for Microsoft Corporation (MSFT) Income Stock")
plt.xlabel("Date")
plt.ylabel("Daily Returns")
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# ### (B) AVERAGE RETURN
# The python code below shows a bar chart of average returns of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. In this code, the yf.download() function is used to get the iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock data from Yahoo Finance, and it calculates daily returns. The mean() function is then used to calculate the average return for each security.
#
# Finally, a horizontal bar chart is created using the plt.subplots() and ax.barh() functions, with the average returns for TLT and MSFT displayed on the y-axis and the security names displayed on the x-axis. The set_xlabel() and set_title() functions are used to add labels to the chart. The resulting chart and codes are shown below.

# %%
# To plot barchart shwoing Average Returns of an ETF and an Income Stock Using Real-Data
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Set the start and end date
start_date = '2021-04-28'
end_date = '2023-04-29'

# Download the data
tlt = yf.download("TLT", start=start_date, end=end_date)
msft = yf.download("MSFT", start=start_date, end=end_date)

# Calculate daily returns
tlt_daily_returns = (tlt['Close'] - tlt['Open']) / tlt['Open']
msft_daily_returns = (msft['Close'] - msft['Open']) / msft['Open']

# Calculate average returns
tlt_avg_return = tlt_daily_returns.mean()
msft_avg_return = msft_daily_returns.mean()

# Create table of average returns
returns_df = pd.DataFrame({"iShares 20+ Year Treasury Bond ETF (TLT)": [tlt_avg_return],
                           "Microsoft Corporation (MSFT) Income Stock": [msft_avg_return]})
returns_df.index = ["Average Return"]

# Show table
print(returns_df)

# Create bar chart of average returns
fig, ax = plt.subplots()
ax.barh(["iShares 20+ Year Treasury Bond ETF (TLT)", "Microsoft Corporation (MSFT) Income Stock"], [tlt_avg_return, msft_avg_return])
ax.set_xlabel("Average Return")
ax.set_title("Average Returns of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                 iShares 20+ Year Treasury Bond ETF (TLT)  \
# Average Return                                  0.000107
#
#                 Microsoft Corporation (MSFT) Income Stock
# Average Return                                   0.000439

# %% [markdown]
# ### (C) PRESENT VALUE AND FUTURE VALUE
# The python code below shows a bar plots of Present Value and Future Value of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock assuming an initial investment of 1000 USD . Python code first imports real data for iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock for the last two years (28-April-2021 to 29-April-2023) from yfinance, calculates daily returns, and shows how to calculate present value and future value assuming an initial investment of 1000 USD. It also creates two bar plots, one for each security, showing the initial investment (present value) and ending value (future value) on the x-axis and the amount on the y-axis as shown  below.

# %%
#To plot bar plots shwoing Present Value and Future Value of an ETF and an Income Stock Using Real-Data
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Download data for TLT and MSFT
tlt = yf.download("TLT", start="2021-04-28", end="2023-04-29")
msft = yf.download("MSFT", start="2021-04-28", end="2023-04-29")

# Calculate daily returns
tlt["Daily Return"] = (tlt["Close"] - tlt["Open"]) / tlt["Open"]
msft["Daily Return"] = (msft["Close"] - msft["Open"]) / msft["Open"]

# Calculate average daily returns
tlt_avg_return = np.mean(tlt["Daily Return"])
msft_avg_return = np.mean(msft["Daily Return"])

# Calculate present value and future value assuming an initial investment of $1,000
initial_investment = 1000
tlt_pv = initial_investment
msft_pv = initial_investment
tlt_fv = tlt_pv * (1 + tlt_avg_return) ** len(tlt)
msft_fv = msft_pv * (1 + msft_avg_return) ** len(msft)
tlt_return = tlt_fv / tlt_pv - 1
msft_return = msft_fv / msft_pv - 1

# Create bar chart of initial and ending values for TLT
tlt_data = pd.DataFrame({"Amount": [tlt_pv, tlt_fv]}, index=["Initial Investment (Present Value)", "Ending Value (Future Value)"])
tlt_data.plot(kind="barh")
plt.title(" iShares 20+ Year Treasury Bond ETF (TLT)  Investment Results")
plt.xlabel("Amount")
plt.show()

# Create bar chart of initial and ending values for MSFT
msft_data = pd.DataFrame({"Amount": [msft_pv, msft_fv]}, index=["Initial Investment (Present Value)", "Ending Value (Future Value)"])
msft_data.plot(kind="barh")
plt.title("Microsoft Corporation (MSFT) Income Stock Investment Results")
plt.xlabel("Amount")
plt.show()

# Display investment results in table format
results = pd.DataFrame({"iShares 20+ Year Treasury Bond ETF (TLT)": [tlt_pv, tlt_fv, tlt_return],
                        "Microsoft Corporation (MSFT) Income Stock": [msft_pv, msft_fv, msft_return]},
                       index=["Initial Investment(Present Value)", "Ending Value (Future Value)", "Total Return"])
print(results)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                                    iShares 20+ Year Treasury Bond ETF (TLT)  \
# Initial Investment(Present Value)                               1000.000000
# Ending Value (Future Value)                                     1055.269007
# Total Return                                                       0.055269
#
#                                    Microsoft Corporation (MSFT) Income Stock
# Initial Investment(Present Value)                                1000.000000
# Ending Value (Future Value)                                      1248.170202
# Total Return                                                        0.248170

# %% [markdown]
# ### (D) VARIANCE
# The python code below shows a bar chart of variance of returns of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock over the period of two years. This code first imports the necessary libraries and gets the data for TLT and MSFT. It then calculates the daily returns and variance of the daily returns for each stock and stores the variances in a Pandas DataFrame. Finally, it creates a horizontal bar plot of the variances for each stock as shown  below.

# %%
#To plot bar plots shwoing Variance of Returns of an ETF and an Income Stock  Real-Data
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Get data for TLT and MSFT
tlt = yf.Ticker("TLT")
msft = yf.Ticker("MSFT")
tlt_data = tlt.history(period="2y")
msft_data = msft.history(period="2y")

# Calculate daily returns for TLT and MSFT
tlt_data["Daily Return"] = (tlt_data["Close"] - tlt_data["Open"]) / tlt_data["Open"]
msft_data["Daily Return"] = (msft_data["Close"] - msft_data["Open"]) / msft_data["Open"]

# Calculate variance of daily returns for TLT and MSFT
tlt_variance = tlt_data["Daily Return"].var()
msft_variance = msft_data["Daily Return"].var()

# Create bar plot of variance of daily returns for TLT and MSFT
var_data = pd.DataFrame({"Variance": [tlt_variance, msft_variance]}, index=["iShares 20+ Year Treasury Bond ETF (TLT)", "Microsoft Corporation (MSFT) Income Stock"])
var_data.plot(kind="barh")
plt.title("Variance of Daily Returns")
plt.xlabel("Variance")
plt.show()

# %% [markdown]
# ### (E) VOLATILITY (STANDARD DEVIATION)
# The python code below  shows a bar plot in Figure 16a of standard deviation (volatility) of returns of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. This code creates a horizontal bar plot with the standard deviation (volatility) of TLT and MSFT on the y-axis and the values on the x-axis as shown below .

# %%
#To plot bar plots shwoing Standard Deviation (Volatility) of Returns of an ETF and an Income Stock  Real-Data
import matplotlib.pyplot as plt

# Calculate the standard deviation of daily returns
tlt_volatility = tlt_daily_returns.std()
msft_volatility = msft_daily_returns.std()

# Create bar chart
fig, ax = plt.subplots()
ax.barh(["iShares 20+ Year Treasury Bond ETF (TLT)", "Microsoft Corporation (MSFT) Income Stock"], [tlt_volatility, msft_volatility])
ax.set_xlabel("Standard Deviation (Volatility)")
ax.set_title("Volatility of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock")
plt.show()

# %% [markdown]
# ### (F) SHARPE RATIO
# The python code below shows a bar plot of Sharpe ratios of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. This code downloads the data for TLT and MSFT, calculates the daily returns, average daily returns, standard deviation (volatility), and Sharpe ratio assuming a risk-free rate of 0%. It then creates a table with the Sharpe ratios and a bar plot of the Sharpe ratios for TLT and MSFT. as shown below.

# %%
#To plot bar plots shwoing Sharpe Ratio of an ETF and an Income Stock  Real-Data
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# Download data
tlt = yf.download("TLT", start="2021-04-28", end="2023-04-29")
msft = yf.download("MSFT", start="2021-04-28", end="2023-04-29")

# Calculate daily returns
tlt["Daily Return"] = (tlt["Close"] - tlt["Open"]) / tlt["Open"]
msft["Daily Return"] = (msft["Close"] - msft["Open"]) / msft["Open"]

# Calculate average daily returns
tlt_avg_return = np.mean(tlt["Daily Return"])
msft_avg_return = np.mean(msft["Daily Return"])

# Calculate standard deviation of daily returns
tlt_volatility = np.std(tlt["Daily Return"])
msft_volatility = np.std(msft["Daily Return"])

# Calculate Sharpe ratio assuming risk-free rate is 0
tlt_sharpe = tlt_avg_return / tlt_volatility
msft_sharpe = msft_avg_return / msft_volatility

# Create table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [tlt_sharpe], 'Microsoft Corporation (MSFT) Income Stock': [msft_sharpe]}
table = pd.DataFrame(data, index=['Sharpe Ratio'])

# Display table
display(table)

# Create bar chart of Sharpe ratios
fig, ax = plt.subplots()
ax.barh(["iShares 20+ Year Treasury Bond ETF (TLT)", "Microsoft Corporation (MSFT) Income Stock"], [tlt_sharpe, msft_sharpe])
ax.set_xlabel("Sharpe Ratio")
ax.set_title("Sharpe Ratios of iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#               iShares 20+ Year Treasury Bond ETF (TLT)  \
# Sharpe Ratio                                  0.013514
#
#               Microsoft Corporation (MSFT) Income Stock
# Sharpe Ratio                                   0.028426

# %% [markdown]
# ### (G) COVARIANCE
# The python code below shows a bar plot  of Covariance between iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. This code displays a table with the covariance between TLT and MSFT, as well as a horizontal bar plot with the same information.

# %%
#To plot bar plots shwoing Covariance between an ETF and an Income Stock  Real-Data
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# Download data for TLT and MSFT
tlt_data = yf.download("TLT", start="2021-04-28", end="2023-04-29")
msft_data = yf.download("MSFT", start="2021-04-28", end="2023-04-29")

# Calculate daily returns
tlt_data["Daily Return"] = (tlt_data["Close"] - tlt_data["Open"]) / tlt_data["Open"]
msft_data["Daily Return"] = (msft_data["Close"] - msft_data["Open"]) / msft_data["Open"]

# Calculate average daily returns
tlt_avg_return = tlt_data["Daily Return"].mean()
msft_avg_return = msft_data["Daily Return"].mean()

# Calculate covariance
covariance = tlt_data["Daily Return"].cov(msft_data["Daily Return"])

# Create table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [covariance], 'Microsoft Corporation (MSFT) Income Stock': [covariance]}
table = pd.DataFrame(data, index=['Covariance'])

# Display table
display(table)

# Create bar chart of covariance
fig, ax = plt.subplots()
ax.barh(["iShares 20+ Year Treasury Bond ETF (TLT)", "Microsoft Corporation (MSFT) Income Stock"], [covariance, covariance])
ax.set_xlabel("Covariance")
ax.set_title("Covariance between iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#             iShares 20+ Year Treasury Bond ETF (TLT)  \
# Covariance                             -4.864068e-07
#
#             Microsoft Corporation (MSFT) Income Stock
# Covariance                              -4.864068e-07

# %% [markdown]
# ### (H) CORRELATION
# The python code below shows a bar plot  of Correlation between iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. . This code displays a table with the covariance between TLT and MSFT, as well as a horizontal bar plot with the same information.

# %%
#To plot bar plots shwoing Correlation between an ETF and an Income Stock  Real-Data
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Downloading the data
tlt = yf.download("TLT", start="2021-04-28", end="2023-04-29")
msft = yf.download("MSFT", start="2021-04-28", end="2023-04-29")

# Daily returns
tlt['Daily Return'] = (tlt['Close'] - tlt['Open']) / tlt['Open']
msft['Daily Return'] = (msft['Close'] - msft['Open']) / msft['Open']

# Average daily return
tlt_avg_daily_return = tlt['Daily Return'].mean()
msft_avg_daily_return = msft['Daily Return'].mean()

# Correlation
correlation = tlt['Daily Return'].corr(msft['Daily Return'])

# Creating the table
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': [correlation], 
        'Microsoft Corporation (MSFT) Income Stock': [correlation]}
table = pd.DataFrame(data, index=['Correlation'])
display(table)

# Creating the bar plot
data = {'iShares 20+ Year Treasury Bond ETF (TLT)': correlation, 
        'Microsoft Corporation (MSFT) Income Stock': correlation}
df = pd.DataFrame(data, index=['Correlation'])
df.plot(kind='barh', legend=False)
plt.title('Correlation between iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock')
plt.xlabel('Correlation')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#              iShares 20+ Year Treasury Bond ETF (TLT)  \
# Correlation                                 -0.003987
#
#              Microsoft Corporation (MSFT) Income Stock
# Correlation                                  -0.003987

# %% [markdown]
# ### (I) SKEWNESS
# The python code below shows a bar plot  of Skewness of returns of  iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock.

# %%
#To plot bar plots shwoing Skewness of Returns of an ETF and an Income Stock  Real-Data
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Download data for TLT and MSFT
tickers = ['TLT', 'MSFT']
data = yf.download(tickers, start='2021-04-28', end='2023-04-29')

# Calculate daily returns
returns = (data['Close'] - data['Open']) / data['Open']

# Calculate skewness
tlt_skewness = returns['TLT'].skew()
msft_skewness = returns['MSFT'].skew()

# Create bar plot
fig, ax = plt.subplots(figsize=(8, 6))
tick_labels = ['iShares 20+ Year Treasury Bond ETF (TLT)', 'Microsoft Corporation (MSFT) Income Stock']
skewness_values = [tlt_skewness, msft_skewness]
ax.bar(tick_labels, skewness_values, width=0.5)
ax.set_xlabel('Investments')
ax.set_ylabel('Skewness')
ax.set_title('Daily Returns Skewness')
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# ### (J) KURTOSIS
#
# The python code below  shows a bar plot of Kurtosis of returns of  iShares 20+ Year Treasury Bond ETF (TLT) and Microsoft Corporation (MSFT) Income Stock. To create a bar plot, we first need to import the matplotlib library and then calculate kurtosis of the daily returns, and display a bar plot:

# %%
#To plot bar plots shwoing Kurtosis of Returns of an ETF and an Income Stock  Real-Data
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Download data from Yahoo Finance
tlt = yf.download('TLT', start='2021-04-28', end='2023-04-29')
msft = yf.download('MSFT', start='2021-04-28', end='2023-04-29')

# Calculate daily returns
tlt['daily_return'] = (tlt['Close'] - tlt['Open']) / tlt['Open']
msft['daily_return'] = (msft['Close'] - msft['Open']) / msft['Open']

# Calculate kurtosis
tlt_kurtosis = pd.DataFrame([tlt['daily_return'].kurtosis()], columns=['iShares 20+ Year Treasury Bond ETF (TLT)'])
msft_kurtosis = pd.DataFrame([msft['daily_return'].kurtosis()], columns=['Microsoft Corporation (MSFT) Income Stock'])

# Create bar plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(tlt_kurtosis.columns, tlt_kurtosis.iloc[0], width=0.4, label='iShares 20+ Year Treasury Bond ETF (TLT)')
ax.bar(msft_kurtosis.columns, msft_kurtosis.iloc[0], width=0.4, label='Microsoft Corporation (MSFT) Income Stock')
ax.set_ylabel('Kurtosis')
ax.set_title('Kurtosis of Daily Returns')
ax.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## STEP 6 TASK (SUMMARIZATION OF THE CONCEPTS USING REAL-WORLD APPLICATIONS)
#
# One example of a journal article discussing these concepts relating to our theme is "The Joint Dynamics of Stock Returns, Volatility, and Trading Volume: A Decomposition Approach" by Torben G. Andersen, Tim Bollerslev, and Francis X. Diebold, published in the Journal of Finance in 2007.
#
# In the article, the authors use a decomposition approach to analyze the joint dynamics of stock returns, volatility, and trading volume. They find that returns, volatility, and trading volume are all closely interrelated and that the volatility of returns tends to increase during periods of high trading volume.
#
# The authors also discuss the concepts of variance and standard deviation/volatility, noting that volatility is a key factor in determining the riskiness of an investment. They explain that covariance measures the degree to which two assets move together and that a positive covariance indicates that the assets tend to move in the same direction, while a negative covariance indicates that they tend to move in opposite directions.
#
# In addition, the article discusses skewness and kurtosis as measures of the distribution of returns. Skewness measures the degree of asymmetry in the distribution, with positive skewness indicating that the distribution is skewed to the right (i.e., there are more extreme positive returns) and negative skewness indicating that the distribution is skewed to the left (i.e., there are more extreme negative returns). Kurtosis measures the degree of peakedness in the distribution, with higher kurtosis indicating that the distribution has fatter tails (i.e., there are more extreme returns).
#
# Overall, the article highlights the importance of understanding these concepts for investors and financial analysts to better assess and manage risk in their portfolios.

# %% [markdown]
# ## CONCLUSION
#
# In this report for the GWP 3 Assignment of the MScFE 600 Financial Data, the group first selected one theme out of the five provided themes, which is “Statistical Related Risk: Volatility & Statistical Related Risk: Correlation” as Step 1 task. Then we created this Jupyter notebook with 3 macro sections as Step 2 Task. For Step 3 task, we explained the concepts of the selected theme which included definitions, equations, formulas, and diagrams with no coding in this section. We furthermore illustrated the concepts using real-world data as Step4 task. For Step 5 task, we provided a graphical representation of the concepts and then, summarized the concepts using real-world applications by referencing a journal article as the final and Step 6 task. Submitted with this report is an executable Jupyter notebook, dataset and the output from the Jupyter notebook after running the code.

# %% [markdown]
# ## REFERENCES
#
# [1] Financial Data Course Lesson Notes, Module 2 & 3, M.Sc. Financial Engineering Program, World Quant University (U.S.A), 2023.
# https://learn.wqu.edu/my-path/courses/financial-data/
#
#
# [2] Financial Markets Course Lesson Notes, Module 1 , 2 & 3, M.Sc. Financial Engineering      Program, World Quant University (U.S.A), 2023.
# https://learn.wqu.edu/my-path/courses/financial-markets/modules/m-3-correlation/tasks/lesson-2-correlation-lesson-notes
#
#
# [3] Submitted Group Work Project 1 Report for Student Group 1015 in Financial Markets
# https://learn.wqu.edu/my-path/courses/financial-markets/modules/m-3-correlation/assessments/fm-group-work-project-1-m-3
#
# [4] Alexander Hess – Pythonista.  “Mastering Markdown & formatting text in JupyterLab.” You Tube, Jan 19, 2021. https://www.youtube.com/watch?v=xmePzVrWqP0
#
# [5] OSPY.  “How to Include Image or Picture in Jupyter Notebook.” You Tube, Aug 17, 2017. https://www.youtube.com/watch?v=xlD8FIM5biA
#
# [6] Torben G. Andersen, Tim Bollerslev, and Francis X. Diebold . "The Joint Dynamics of Stock Returns, Volatility, and Trading Volume: A Decomposition Approach."   Journal of Finance, 2007,
